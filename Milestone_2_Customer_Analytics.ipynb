# %% [markdown]
# # **Customer Analytics: Milestone 2 Project**
#
# ### In this assignment I have been given a data set customer_train.csv a subset of a larger data set for all customers, in the aims of storing the data more efficiently. the requirements I have been given are:
# - Columns containing categories with only two factors must be stored as Booleans (bool).
#
# - Columns containing integers only must be stored as 32-bit integers - (int32).
#
# - Columns containing floats must be stored as 16-bit floats (float16).
#
# - Columns containing nominal categorical data must be stored as the category data type.
#
# - Columns containing ordinal categorical data must be stored as ordered categories, and not mapped to numerical values, with an order that reflects the natural order of the column.
#
# - The DataFrame should be filtered to only contain students with 10 or more years of experience at companies with at least 1000 employees, as their recruiter base is suited to more experienced professionals at enterprise companies.

# %% [markdown]
# # Importing Data & Libraries
# Before starting any modifications to the data, I must import the proper packages and the csv file which is done below.

# %%
#These libraries are built into google colab, where these libraries are already
#incorporated, if viewing this file using a different application, it may be
#neccessary to do a pip install
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

#data must be uploaded first to google colab, and will be deleted once the
#this when runtime is cut. you must select the data you want to be uploaded
#manually. This will vary from application, and may need some changing.

from google.colab import files
uploaded = files.upload()

#dataset stored in a dataframe
ds_jobs = pd.read_csv("customer_train.csv")

#a copy of ds_jobs to adjust data in
ds_jobs_transformed = ds_jobs.copy()
# Out:
#      <input type="file" id="files-bff280bb-a451-4819-9c4a-7e8f8664ac43" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bff280bb-a451-4819-9c4a-7e8f8664ac43">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Analysis of Data
# Next, it is a good Idea to check what exactly each column in the dataframe has as its values.

# %%
ds_jobs_transformed.head()
# Out:
#    student_id      city  city_development_index gender  \
# 0        8949  city_103                   0.920   Male
# 1       29725   city_40                   0.776   Male
# 2       11561   city_21                   0.624    NaN
# 3       33241  city_115                   0.789    NaN
# 4         666  city_162                   0.767   Male
#
#        relevant_experience enrolled_university education_level  \
# 0  Has relevant experience       no_enrollment        Graduate
# 1   No relevant experience       no_enrollment        Graduate
# 2   No relevant experience    Full time course        Graduate
# 3   No relevant experience                 NaN        Graduate
# 4  Has relevant experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM        >20          NaN             NaN            1
# 1             STEM         15        50-99         Pvt Ltd           >4
# ...

# %% [markdown]
# we can see that there are 14 different columns, each with their own unqiue values. The first task given was to find values which can be stored as bools (values which only have two factors). This can be done by checking each column with a frequency using value_counts

# %%
print(ds_jobs_transformed['student_id'].value_counts(dropna = False))
# Out:
# student_id
# 23834    1
# 8949     1
# 29725    1
# 11561    1
# 33241    1
#         ..
# 29452    1
# 699      1
# 27107    1
# 402      1
# 28806    1
# Name: count, Length: 19158, dtype: int64

# %% [markdown]
# As we can see, each value is unique which means that this data should not be stored as a bool, rather, an integer (32 bit)

# %%
print(ds_jobs_transformed['city'].value_counts(dropna = False))
# Out:
# city
# city_103    4355
# city_21     2702
# city_16     1533
# city_114    1336
# city_160     845
#             ...
# city_111       3
# city_129       3
# city_121       3
# city_140       1
# city_171       1
# Name: count, Length: 123, dtype: int64
